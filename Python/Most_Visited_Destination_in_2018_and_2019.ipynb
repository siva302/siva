# %%
import pandas as pd

# %%
d=pd.read_csv(r'C:\Users\asiva\OneDrive\Desktop\Most_Visited_Destination_in_2018_and_2019.csv')

# %%
d.shape
# Out:
# (50, 5)

# %%
f=pd.DataFrame(d)
f
# Out:
#     Unnamed: 0           Destination International  tourist  arrivals  (2019)  \
# 0            0                 Egypt                             13.0 million
# 1            1               Morocco                             12.9 million
# 2            2          South Africa                             10.2 million
# 3            3               Tunisia                              9.4 million
# 4            4               Algeria                              2.4 million
# 5            5              Zimbabwe                              2.3 million
# 6            6            Mozambique                              2.0 million
# 7            7           Ivory Coast                                        –
# 8            8                 Kenya                                        –
# 9            9              Botswana                                        –
# 10          10         United States                             79.3 million
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0', 'Destination', 'International  tourist  arrivals  (2019)',
#        'International  tourist  arrivals  (2018)', 'Region'],
#       dtype='object')

# %%
d.isnull().sum()
# Out:
# Unnamed: 0                                  0
# Destination                                 0
# International  tourist  arrivals  (2019)    0
# International  tourist  arrivals  (2018)    0
# Region                                      0
# dtype: int64

# %%
k.head(2)
# Out:
# Africa     10
# America    10
# Name: Region, dtype: int64

# %%
g=d['International  tourist  arrivals  (2019)'].value_counts()
g
# Out:
# –               3
# 13.0 million    2
# 4.5 million     2
# 6.4 million     2
# 17.5 million    2
# 4.6 million     1
# 9.1 million     1
# 15.5 million    1
# 90.9 million    1
# 83.5 million    1
# 51.2 million    1
# 64.5 million    1
# 39.4 million    1
# 39.6 million    1
# 2.1 million     1
# 31.3 million    1
# 2.5 million     1
# 17.9 million    1
# 24.5 million    1
# 20.1 million    1
# 16.7 million    1
# 3.8 million     1
# 31.9 million    1
# 18.6 million    1
# 18.0 million    1
# 12.9 million    1
# 10.2 million    1
# 9.4 million     1
# 2.4 million     1
# 2.3 million     1
# 2.0 million     1
# 79.3 million    1
# 45.0 million    1
# 22.1 million    1
# 7.4 million     1
# 5.2 million     1
# 4.3 million     1
# 4.2 million     1
# 65.7 million    1
# 39.8 million    1
# 32.2 million    1
# 26.1 million    1
# 23.8 million    1
# 1.9 million     1
# Name: International  tourist  arrivals  (2019), dtype: int64

# %%
k=d['Region'].value_counts()
k
# Out:
# Africa                10
# America               10
# Asia & The Pacific    10
# Europe                10
# West Asia             10
# Name: Region, dtype: int64

# %% [markdown]
# import numpy as np

# %%
d1=np.array(d)

# %%
d1.shape
# Out:
# (50, 5)

# %%
type(d1)
# Out:
# numpy.ndarray

# %%
m=np.max(k)
m
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 m=np.max(k)
#       2 m
#
# File <__array_function__ internals>:180, in amax(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2793, in amax(a, axis, out, keepdims, initial, where)
#    2677 @array_function_dispatch(_amax_dispatcher)
#    2678 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2679          where=np._NoValue):
#    2680     """
#    2681     Return the maximum of an array or maximum along an axis.
#    2682
#    (...)
#    2791     5
#    2792     """
# -> 2793     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2794                           keepdims=keepdims, initial=initial, where=where)
#
# ...

# %%
for i in k:
    if i=='Africa':
        print(i)
    else:
        print('no')
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# ...
