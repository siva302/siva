# %%
# %run tabulate.ipynb
while True:
    print('='*80)
    print('1.Insert\n2.Upadte\n3.Select\n4.Exist')
    print('='*80)
    choice=int(input('enter your choice: '))
    print('choice')
    if choice==1:
        ins()
                   
    elif choice==2:
        up()
    elif choice==3:
        sel()
    elif choice==4:
        break
    else:
        print("out of choice")
        break
    fetch_all()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ok
# ...
# 1.Insert
# 2.Upadte
# 3.Select
# 4.Exist
# ...
# enter your choice: 2
# choice
# enter the id : 13
# enter a name: sujatha
# enter a id: 13
# updated
# +-----+---------+-------+---------+-----------+------------+
# | id  |  name   | p_age | address |  salary   |   email    |
# +-----+---------+-------+---------+-----------+------------+
# |  1  |  siva   |  22   |   ktc   | 26000.00  |  siva@123  |
# |  2  |   sai   |  19   |   atp   | 36000.00  |  kavi@123  |
# |  3  | chinna  |  23   |   ptp   |  3600.00  | chinna@123 |
# |  4  |   tan   |  15   |   ktm   | 31000.00  |  ravi@123  |
# |  5  | vishnu  |  20   |   dmm   |  3500.00  | vishnu@123 |
# |  6  |  rasul  |  23   |   atp   |  5000.00  |   rasul    |
# |  7  |   ram   |  25   |   kmm   | 520000.00 |    ram     |
# |  8  | ramesh  |  30   |   dmm   | 500000.00 |    ram     |
# | 13  | sujatha |  30   |   ktc   | 58222.00  |    suji    |
# ...
